# %%
#import lib
import json
import os
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Get all non-NULL App ID

# %%
#array for app id
appID = []

for year in range(2008,2023):
    
    # https://steamspy.com/year/{year}
    URL = f'https://steamspy.com/year/{year}'
    page = requests.get(URL)

    soup = BeautifulSoup(page.content)
    table = soup.find('table')
    links = table.findAll('a')
    
    myStr = f"Debug M: Year: {year}. Get {str(len(links))} links!\n";
    os.write(1,myStr.encode())

    for link in range(len(links)):
        appID.append(links[link].get('href').split('/')[2])

    
myStr = f"Debug M: Done! Total links {str(len(appID))} collected!\n";
os.write(1,myStr.encode())
# Out:
# 43

# %%
print(appID)
# Out:
# ['1245620', '1593500', '1345860', '1221250', '1190170', '1659040', '1446780', '1850570', '1142710', '553420', '374190', '1617030', '1599560', '1621310', '1574580', '1837750', '1147550', '1220100', '1410640', '987840', '1114290', '1097350', '1475810', '1218210', '1061880', '515960', '1172190', '1036890', '1368030', '1028350', '581660', '1132910', '1045610', '957710', '1491150', '1169760', '1069080', '1340360', '1238480', '1467340', '1549070', '1494910', '1424930', '1332150', '674690', '1456230', '308080', '588120', '1168840', '1190150', '1546280', '1546930', '725100', '906870', '969680', '592640', '511270', '865810', '951860', '1160950', '1152200', '1129540', '1313630', '1296770', '1347800', '1373950', '1400060', '1416220', '1367460', '1474120', '1498110', '1493880', '1532640', '1532440', '1526190', '1473830', '1553800', '1553810', '1556740', '1309000', '1513260', '618000', '1716530', '1614030', '1571910', '1543730', '1565440', '1556170', '1520880', '1669350', '1622780', '1706850', '1707630', '1723320', '1681810', '1703330', '1607130', '1579920', '1683430', '1601280', '1678590', '1189070', '1602970', '1600830', '1595290', '1595400', '1594010', '1665820', '1650430', '1693760', '1683950', '1667550', '1667130', '1702380', '1567050', '1691300', '1731240', '1742470', '1721570', '1701660', '1746760', '1749120', '1671510', '1723930', '1753690', '1748050', '1715490', '1639420', '1745310', '1755530', '1747160', '1563070', '1711980', '1770210', '1751470', '1788380', '1609010', '1745030', '1798340', '1799890', '1795440', '1798980', '1729600', '1737100', '1639210', '1803720', '1813320', '1810320', '1806120', '1786110', '1814310', '1814540', '1794420', '1787910', '1803450', '1587290', '1788740', '1800860', '1800580', '1822040', '1769750', '1820810', '1791310', '1797790', '1808240', '1693950', '1800080', '1823380', '1816560', '1767840', '1799590', '1831400', '1795310', '1828950', '1825050', '1833840', '1825130', '1830240', '1815800', '1665650', '1819040', '1677130', '1836420', '1690210', '1781060', '1837060', '1837700', '1842310', '1841580', '1830620', '1844260', '1844270', '1844280', '1844300', '1227370', '1840570', '1842360', '1842370', '1844560', '1288920', '1808910', '1834960', '1830950', '1839150', '1845710', '1841610', '1847200', '1814670', '1846800', '1844550', '1850620', '1848940', '1847990', '1806110', '1843290', '1845480', '1838650', '1853720', '1853180', '1840850', '1812890', '1846920', '1844540', '1553210', '1854970', '1853400', '1853780', '1834720', '1855020', '1681670', '1811520', '1856990', '1855910', '1853390', '1857020', '1708250', '1835070', '1853660', '1801890', '1852410', '1859500', '1859980', '1616070', '1845040', '1636190', '1768640', '1858260', '1783110', '1857570', '1859670', '1856000', '1861340', '1863020', '1863980', '1776270', '1848290', '1858940', '1830780', '1848310', '1836590', '1866460', '1698030', '1820940', '1859540', '1841230', '1793300', '1860800', '1831260', '1862200', '1857890', '1839570', '1859890', '1851850', '1839340', '1839350', '1839360', '1865500', '1849000', '1855410', '1837210', '1863700', '1810350', '1870570', '1801950', '1800030', '1852300', '1867200', '1734600', '1867290', '1867400', '1834430', '1841030', '1866310', '1851190', '1869330', '1864090', '1869090', '1871590', '1852220', '1866670', '1875250', '1835830', '1780310', '1697040', '1811920', '1751070', '1873430', '1692270', '1871020', '1874770', '1874420', '1694840', '1869370', '1873420', '1817890', '1820020', '1840810', '1687460', '1820330', '1627030', '1879790', '1734350', '1868730', '1482400', '1873180', '1823400', '1883670', '1882670', '1856860', '1862980', '1789130', '1842380', '1869020', '1873000', '1832690', '1883680', '1877980', '1881140', '1879690', '1882700', '1883420', '1643520', '1880180', '1865210', '1884380', '1882050', '1881210', '1866600', '1712510', '1860930', '1884720', '1882160', '1880700', '1879670', '1878280', '1875800', '1874220', '1830170', '1888210', '1779070', '1884140', '1875750', '1880030', '1809900', '1890810', ' ...

# %% [markdown]
# # Data collection

# %%
#open file stream    
file = open("GameData_cleaned.txt", "a" , encoding="ANSI")

#Loop through all appid
for count in range(0 , len(appID)):

    #URL
    url = 'https://steamspy.com/api.php?request=appdetails&appid='+ str(tempID[count])
    
   #Content type
    headers = {'Content-type': 'application/json'}

    #API GET
    response = requests.get(url, headers = headers)

    #if response 200
    if(response.status_code == 200):
        
        #Write header after frist request
        if(count == 0):
             
            temStr = "" #header string
            tempData = "" #temp string
            
            #Loop through all datas in json 
            for key,val in response.json().items():
                #append header string with ","
                temStr += (key + ",")
                
                #if key == owners
                if(key == "owners"):
                    #sub string to get biggest num and remove comma
                    tempData += (str(val).split()[2].replace(',', '') + ",")
                elif(type(val) == dict):
                    temp = ""
                    for key,val in val.items():
                        temp += (str(val) + ",")

                    tempData = tempData +'"'+ temp[:-1] + '",'

                elif(key == "languages" or key == "genre" or key == "developer" or key == "publisher" or key == "name"):


                    tempData = tempData + '"'+ str(val) + '",'
                    
                elif(key == "price" or key == "initialprice"):

                    if(len(val) >= 2 ):
                        tempData = tempData + str(str(val)[:-2] + "."+str(val)[-2:]) + ','
                    else:
                        tempData = tempData + '0.0' + str(val) + ','

                else:
                    tempData += (str(val) + ",")

            #write header and data
            file.write( temStr[:-1] + '\n' + tempData[:-1] + '\n')
            
        else:
            #temp string
            tempData = ""
            
            for key,val in response.json().items():
                
                if(key == "name" and val == None): 
                    tempData = "" 
                    break
                
                if(key == "owners"):
                    tempData += (str(val).split()[2].replace(',', '') + ",")
                elif(type(val) == dict):
                    temp = ""
                    for key,val in val.items():
                        temp += (str(val) + ",")

                    tempData = tempData +'"'+ temp[:-1] + '",'

                elif(key == "languages" or key == "genre" or key == "developer" or key == "publisher" or key == "name"):


                    tempData = tempData + '"'+ str(val) + '",'
                elif(key == "price" or key == "initialprice"):

                    if(len(val) >= 2 ):
                        tempData = tempData + str(str(val)[:-2] + "."+str(val)[-2:]) + ','
                    else:
                        tempData = tempData + '0.0' + str(val) + ','
                else:
                    tempData += (str(val) + ",")
            
            
            #write header and data
            if(str(tempData).strip() !="" ):
                file.write(tempData[:-1] + '\n' )
                myStr = "Debug M: Writing Data "+ str(count) +" to file\n";
                os.write(1,myStr.encode())
            
            myStr = "Debug M: Current count "+ str(count) +"\n";
            os.write(1,myStr.encode())
    

file.close()

os.write(1,b"File stream closed!\n")
os.write(1,b"Collection Done !\n")
# Out:
# 18

# %% [markdown]
# # File close

# %%
file.close()

# %% [markdown]
# # Testing

# %%
#URL
url = 'https://steamspy.com/api.php?request=appdetails&appid=544400'

#Content type
headers = {'Content-type': 'application/json'}

#API GET
response = requests.get(url, headers = headers)

#temp string
tempData = ""

#if response 200
if(response.status_code == 200):


    temStr = "" #header string
    tempData = "" #temp string

    for key,val in response.json().items():

        if(key == "name" and val == None): 
            tempData = "" 
            break

        if(key == "owners"):
            tempData += (str(val).split()[2].replace(',', '') + ",")

        elif(type(val) == dict):

            temp = ""
            for key,val in val.items():
                temp += (str(val) + ",")

            tempData = tempData +'"'+ temp[:-1] + '",'

        elif(key == "languages" or key == "genre" or key == "developer" or key == "publisher" or key == "name"):

            tempData = tempData + '"'+ str(val) + '",'

        elif(key == "price" or key == "initialprice"):

            if(len(val) >= 2 ):
                tempData = tempData + str(str(val)[:-2] + "."+str(val)[-2:]) + ','
            else:
                tempData = tempData + '0.0' + str(val) + ','
        else:
            tempData += (str(val) + ",")


print(tempData[:-1])
# Out:
# 544400,"GUNGUNGUN","Mystery Egg Games","Mystery Egg Games",,19,1,0,20000,0,0,0,0,4.99,4.99,0,0,"English","Action, Indie","43,42,22,14,12,11,10,10"

# %%
import requests
from bs4 import BeautifulSoup

# https://steamspy.com/year/2021
URL = 'https://steamspy.com/year/2021'
page = requests.get(URL)

soup = BeautifulSoup(page.content)
table = soup.find('table')
links = table.findAll('a')

print(f"Get {str(len(links))} links!")

appID = []

for link in range(len(links)):
    appID.append(links[link].get('href').split('/')[2])

print(len(appID))
