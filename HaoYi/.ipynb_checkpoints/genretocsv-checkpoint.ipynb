# %%
import csv
import pandas as pd
import numpy as np

# %%
file = pd.read_csv('GameData_cleaned.txt', keep_default_na=False , encoding='utf8')
print(file)
genre = pd.DataFrame(file, columns=['genre'])
print(genre)
lang = pd.DataFrame(file, columns=['languages'])
print(lang)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-b7ffff1155fb> in <module>
# ----> 1 file = pd.read_csv('GameData_cleaned.txt', keep_default_na=False , encoding='utf8')
#       2 print(file)
#       3 genre = pd.DataFrame(file, columns=['genre'])
#       4 print(genre)
#       5 lang = pd.DataFrame(file, columns=['languages'])
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1872         if kwds.get("compression") is None and encoding:
#    1873             if isinstance(src, str):
# -> 1874                 src = open(src, "rb")
#    1875                 self.handles.append(src)
#    1876
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GameData_cleaned.txt'

# %%
def duplicator(lst):
    check = []
    for i in lst:
        if i in check:
#             print("found duplicate! == ", i)
            continue
        else:
#             print("appending ", i)
            check.append(i)
    length = len(check)
    while (length < 7):
#         print("check length: ", length, " ----- check: ", check)
        check.append("")
        length += 1
    return check

def countgenre(lst, counter):
    for i in lst:
        if i in counter:
            continue
        else:
            counter.append(i)
    return counter

# %%
newgenre = pd.DataFrame(columns=['genre1', 'genre2', 'genre3', 'genre4', 'genre5', 'genre6', 'genre7'])
genrelist = []
counter = 1
# max = 0
for i in range(len(genre)):
    if genre['genre'][i] == '':
        strlist = []
    else:
        string = genre['genre'][i]
        strlist = string.split(', ')
#         genrelist = countgenre(strlist, genrelist)
    strlist = duplicator(strlist)
#     if len(strlist) > max:
#         max = len(strlist)
    strseries = pd.Series(strlist, index=newgenre.columns)
    newgenre = newgenre.append(strseries, ignore_index=True)
#     print(len(strlist), strlist)
#         print(strlist)
# print("max: ", max, "\n\n")
print(newgenre)
# print(genrelist)

# %%
newgenre.to_csv('genres.csv', index=False)

# %%
def languagefilter(lst, check):
    newlist = []
    print('\nList: ', lst, '\n')
    length = len(lst)
    for i in range(length):
        if "English" in lst[i]:
            check[0] = "Yes"
            lst[i] = "removed"
        elif "Chinese" in lst[i]:
            check[1] = "Yes"
            lst[i] = "removed"
        elif "French" in lst[i]:
            check[2] = "Yes"
            lst[i] = "removed"
        elif "German" in lst[i]:
            check[3] = "Yes"
            lst[i] = "removed"
        elif "Italian" in lst[i]:
            check[4] = "Yes"
            lst[i] = "removed"
        elif "Spanish" in lst[i]:
            check[5] = "Yes"
            lst[i] = "removed"
        
    for j in lst:
        print("j: ", j)
        if j == "removed":
            continue
        else:
            newlist.append(j)
    
    
    if check[5] == "Yes":
        newlist.insert(0, "Spanish")
    
    if check[4] == "Yes":
        newlist.insert(0, "Italian")
    
    if check[3] == "Yes":
        newlist.insert(0, "German")
    
    if check[2] == "Yes":
        newlist.insert(0, "French")
   
    if check[1] == "Yes":
        newlist.insert(0, "Chinese")
    
    if check[0] == "Yes":
        newlist.insert(0, "English")
    
    check[6] = len(newlist)
    check[7] = newlist
    print(check, '\n\n')
    return check

# %%
newlang = pd.DataFrame(columns=["English", "Chinese", "French", "German", "Italian", "Spanish", "Total Languages", "Collection"])
langlist = []

# max = 0
for i in range(len(lang)):
    toappend = ["No", "No", "No", "No", "No", "No", 0, lang['languages'][i]]
    if lang['languages'][i] == '':
        strlist = []
    else:
        string = lang['languages'][i]
        strlist = string.split(', ')
#         langlist = countgenre(strlist, langlist)
    toappend = languagefilter(strlist, toappend)
#     if len(strlist) > max:
#         max = len(strlist)
    strseries = pd.Series(toappend, index=newlang.columns)
    newlang = newlang.append(strseries, ignore_index=True)
#     print("toappend: ", toappend, '\n\n\n')
#         print(strlist)
# print("max: ", max, "\n\n")
# print(newgenre)
# print(langlist)
# Out:
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Simplified Chinese', 'Traditional Chinese', 'Korean']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 7, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Korean']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Korean', 'Russian', 'Simplified Chinese', 'Traditional Chinese']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# j:  Russian
# j:  removed
# j:  removed
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Korean', 'Russian']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Korean', 'Russian', 'Simplified Chinese', 'Traditional Chinese']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# j:  Russian
# j:  removed
# j:  removed
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Korean', 'Russian']]
#
#
#
# List:  ['English', 'French', 'German', 'Korean']
#
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# ['Yes', 'No', 'Yes', 'Yes', 'No', 'No', 4, ['English', 'French', 'German', 'Korean']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Korean', 'Russian', 'Simplified Chinese', 'Traditional Chinese']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# j:  Russian
# j:  removed
# j:  removed
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Korean', 'Russian']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Simplified Chinese', 'Traditional Chinese', 'Korean']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 7, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Korean']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Simplified Chinese', 'Traditional Chinese', 'Korean']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 7, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Korean']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Simplified Chinese', 'Traditional Chinese', 'Korean']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 7, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Korean']]
#
#
#
# List:  ['English', 'French', 'German']
#
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'No', 'No', 3, ['English', 'French', 'German']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Korean', 'Spanish - Spain', 'Russian', 'Simplified Chinese', 'Traditional Chinese', 'Dutch', 'Danish', 'Finnish', 'Japanese', 'Norwegian', 'Polish', 'Portuguese', 'Swedish', 'Thai']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# j:  removed
# j:  Russian
# j:  removed
# j:  removed
# j:  Dutch
# j:  Danish
# j:  Finnish
# j:  Japanese
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  Swedish
# j:  Thai
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 17, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Korean', 'Russian', 'Dutch', 'Danish', 'Finnish', 'Japanese', 'Norwegian', 'Polish', 'Portuguese', 'Swedish', 'Thai']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Japanese', 'Korean', 'Spanish - Spain', 'Russian', 'Simplified Chinese', 'Traditional Chinese', 'Thai', 'Turkish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese
# j:  Korean
# j:  removed
# j:  Russian
# j:  removed
# j:  removed
# j:  Thai
# j:  Turkish
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 11, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Japanese', 'Korean', 'Russian', 'Thai', 'Turkish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Japanese', 'Spanish - Spain', 'Russian', 'Simplified Chinese', 'Traditional Chinese', 'Thai', 'Korean']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese
# j:  removed
# j:  Russian
# j:  removed
# j:  removed
# j:  Thai
# j:  Korean
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 10, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Japanese', 'Russian', 'Thai', 'Korean']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Russian', 'Simplified Chinese', 'Traditional Chinese', 'Korean']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# j:  removed
# j:  removed
# j:  Korean
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Russian', 'Korean']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Korean', 'Spanish - Spain', 'Russian', 'Simplified Chinese', 'Traditional Chinese', 'Dutch', 'Danish', 'Finnish', 'Japanese', 'Norwegian', 'Polish', 'Portuguese', 'Swedish', 'Thai']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# j:  removed
# j:  Russian
# j:  removed
# j:  removed
# j:  Dutch
# j:  Danish
# j:  Finnish
# j:  Japanese
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  Swedish
# j:  Thai
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 17, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Korean', 'Russian', 'Dutch', 'Danish', 'Finnish', 'Japanese', 'Norwegian', 'Polish', 'Portuguese', 'Swedish', 'Thai']]
#
#
#
# List:  ['English', 'French', 'German', 'Russian', 'Danish', 'Dutch', 'Finnish', 'Italian', 'Japanese', 'Norwegian', 'Polish', 'Portuguese', 'Simplified Chinese', 'Spanish - Spain', 'Swedish', 'Traditional Chinese', 'Korean']
#
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  removed
# j:  Japanese
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  removed
# j:  removed
# j:  Swedish
# j:  removed
# j:  Korean
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 16, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Russian', 'Danish', 'Dutch', 'Finnish', 'Japanese', 'Norwegian', 'Polish', 'Portuguese', 'Swedish', 'Korean']]
#
#
#
# List:  ['English', 'French', 'German', 'Russian', 'Danish', 'Dutch', 'Finnish', 'Italian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Simplified Chinese', 'Spanish - Spain', 'Swedish', 'Traditional Chinese ']
#
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  removed
# j:  removed
# j:  Swedish
# j:  removed
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 16, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Russian', 'Danish', 'Dutch', 'Finnish', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Swedish']]
#
#
#
# List:  ['English', 'French', 'German', 'Russian', 'Danish', 'Dutch', 'Finnish', 'Italian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Simplified Chinese', 'Spanish - Spain', 'Swedish', 'Traditional Chinese']
#
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  removed
# j:  removed
# j:  Swedish
# j:  removed
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 16, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Russian', 'Danish', 'Dutch', 'Finnish', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Swedish']]
#
#
#
# List:  ['English', 'Danish', 'Dutch', 'Finnish', 'French', 'German', 'Italian', 'Japanese', 'Norwegian', 'Polish', 'Portuguese', 'Russian', 'Simplified Chinese', 'Spanish - Spain', 'Swedish', 'Traditional Chinese', 'Korean', 'Czech', 'Hungarian', 'Portuguese - Brazil', 'Turkish', 'Greek', 'Bulgarian', 'Romanian', 'Thai', 'Ukrainian']
#
# j:  removed
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  Russian
# j:  removed
# j:  removed
# j:  Swedish
# j:  removed
# j:  Korean
# j:  Czech
# j:  Hungarian
# j:  Portuguese - Brazil
# j:  Turkish
# j:  Greek
# j:  Bulgarian
# j:  Romanian
# j:  Thai
# j:  Ukrainian
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 25, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Danish', 'Dutch', 'Finnish', 'Japanese', 'Norwegian', 'Polish', 'Portuguese', 'Russian', 'Swedish', 'Korean', 'Czech', 'Hungarian', 'Portuguese - Brazil', 'Turkish', 'Greek', 'Bulgarian', 'Romanian', 'Thai', 'Ukrainian']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Spanish - Spain', 'Russian', 'Danish', 'Dutch', 'Finnish', 'Italian', 'Japanese', 'Norwegian', 'Polish', 'Portuguese', 'Simplified Chinese', 'Swedish', 'Traditional Chinese', 'Korean']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  removed
# j:  Japanese
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  removed
# j:  Swedish
# j:  removed
# j:  Korean
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 16, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Russian', 'Danish', 'Dutch', 'Finnish', 'Japanese', 'Norwegian', 'Polish', 'Portuguese', 'Swedish', 'Korean']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'Danish', 'Dutch', 'Finnish', 'French', 'German', 'Italian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Russian', 'Simplified Chinese', 'Spanish - Spain', 'Swedish', 'Traditional Chinese', 'Hungarian', 'Turkish', 'Bulgarian', 'Czech', 'Greek', 'Portuguese - Brazil', 'Romanian', 'Spanish - Latin America', 'Thai', 'Ukrainian', 'Vietnamese']
#
# j:  removed
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  Russian
# j:  removed
# j:  removed
# j:  Swedish
# j:  removed
# j:  Hungarian
# j:  Turkish
# j:  Bulgarian
# j:  Czech
# j:  Greek
# j:  Portuguese - Brazil
# j:  Romanian
# j:  removed
# j:  Thai
# j:  Ukrainian
# j:  Vietnamese
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 26, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Danish', 'Dutch', 'Finnish', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Russian', 'Swedish', 'Hungarian', 'Turkish', 'Bulgarian', 'Czech', 'Greek', 'Portuguese - Brazil', 'Romanian', 'Thai', 'Ukrainian', 'Vietnamese']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'Bulgarian', 'Czech', 'Danish', 'Dutch', 'Finnish', 'French', 'German', 'Greek', 'Hungarian', 'Italian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Portuguese - Brazil', 'Romanian', 'Russian', 'Simplified Chinese', 'Spanish - Spain', 'Swedish', 'Thai', 'Traditional Chinese', 'Turkish', 'Ukrainian', 'Spanish - Latin America', 'Vietnamese']
#
# j:  removed
# j:  Bulgarian
# j:  Czech
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  removed
# j:  removed
# j:  Greek
# j:  Hungarian
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  Portuguese - Brazil
# j:  Romanian
# j:  Russian
# j:  removed
# j:  removed
# j:  Swedish
# j:  Thai
# j:  removed
# j:  Turkish
# j:  Ukrainian
# j:  removed
# j:  Vietnamese
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 26, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Bulgarian', 'Czech', 'Danish', 'Dutch', 'Finnish', 'Greek', 'Hungarian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Portuguese - Brazil', 'Romanian', 'Russian', 'Swedish', 'Thai', 'Turkish', 'Ukrainian', 'Vietnamese']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Spanish - Spain', 'Czech', 'Danish', 'Dutch', 'Finnish', 'Hungarian', 'Italian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Romanian', 'Russian', 'Simplified Chinese', 'Swedish', 'Thai', 'Traditional Chinese', 'Turkish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Czech
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  Hungarian
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  Romanian
# j:  Russian
# j:  removed
# j:  Swedish
# j:  Thai
# j:  removed
# j:  Turkish
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 21, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Czech', 'Danish', 'Dutch', 'Finnish', 'Hungarian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Romanian', 'Russian', 'Swedish', 'Thai', 'Turkish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Spanish - Spain', 'Czech', 'Danish', 'Dutch', 'Finnish', 'Hungarian', 'Italian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Romanian', 'Russian', 'Simplified Chinese', 'Swedish', 'Thai', 'Traditional Chinese', 'Turkish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Czech
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  Hungarian
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  Romanian
# j:  Russian
# j:  removed
# j:  Swedish
# j:  Thai
# j:  removed
# j:  Turkish
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 21, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Czech', 'Danish', 'Dutch', 'Finnish', 'Hungarian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Romanian', 'Russian', 'Swedish', 'Thai', 'Turkish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'Czech', 'Danish', 'Dutch', 'Finnish', 'French', 'German', 'Hungarian', 'Italian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Portuguese - Brazil', 'Romanian', 'Russian', 'Simplified Chinese', 'Spanish - Spain', 'Swedish', 'Thai', 'Traditional Chinese', 'Turkish', 'Bulgarian', 'Ukrainian', 'Greek', 'Spanish - Latin America', 'Vietnamese']
#
# j:  removed
# j:  Czech
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  removed
# j:  removed
# j:  Hungarian
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  Portuguese - Brazil
# j:  Romanian
# j:  Russian
# j:  removed
# j:  removed
# j:  Swedish
# j:  Thai
# j:  removed
# j:  Turkish
# j:  Bulgarian
# j:  Ukrainian
# j:  Greek
# j:  removed
# j:  Vietnamese
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 26, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Czech', 'Danish', 'Dutch', 'Finnish', 'Hungarian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Portuguese - Brazil', 'Romanian', 'Russian', 'Swedish', 'Thai', 'Turkish', 'Bulgarian', 'Ukrainian', 'Greek', 'Vietnamese']]
#
#
#
# List:  ['English', 'Czech', 'Danish', 'Dutch', 'Finnish', 'French', 'German', 'Hungarian', 'Italian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Portuguese - Brazil', 'Romanian', 'Russian', 'Simplified Chinese', 'Spanish - Spain', 'Swedish', 'Thai', 'Traditional Chinese', 'Turkish', 'Bulgarian', 'Ukrainian', 'Greek', 'Spanish - Latin America', 'Vietnamese']
#
# j:  removed
# j:  Czech
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  removed
# j:  removed
# j:  Hungarian
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  Portuguese - Brazil
# j:  Romanian
# j:  Russian
# j:  removed
# j:  removed
# j:  Swedish
# j:  Thai
# j:  removed
# j:  Turkish
# j:  Bulgarian
# j:  Ukrainian
# j:  Greek
# j:  removed
# j:  Vietnamese
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 26, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Czech', 'Danish', 'Dutch', 'Finnish', 'Hungarian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Portuguese - Brazil', 'Romanian', 'Russian', 'Swedish', 'Thai', 'Turkish', 'Bulgarian', 'Ukrainian', 'Greek', 'Vietnamese']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['Danish', 'Dutch', 'English', 'Finnish', 'French', 'German', 'Italian', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Russian', 'Simplified Chinese', 'Spanish - Spain', 'Swedish', 'Traditional Chinese', 'Hungarian', 'Turkish', 'Bulgarian', 'Czech', 'Greek', 'Portuguese - Brazil', 'Romanian', 'Spanish - Latin America', 'Thai', 'Ukrainian', 'Vietnamese']
#
# j:  Danish
# j:  Dutch
# j:  removed
# j:  Finnish
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Norwegian
# j:  Polish
# j:  Portuguese
# j:  Russian
# j:  removed
# j:  removed
# j:  Swedish
# j:  removed
# j:  Hungarian
# j:  Turkish
# j:  Bulgarian
# j:  Czech
# j:  Greek
# j:  Portuguese - Brazil
# j:  Romanian
# j:  removed
# j:  Thai
# j:  Ukrainian
# j:  Vietnamese
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 26, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Danish', 'Dutch', 'Finnish', 'Japanese', 'Korean', 'Norwegian', 'Polish', 'Portuguese', 'Russian', 'Swedish', 'Hungarian', 'Turkish', 'Bulgarian', 'Czech', 'Greek', 'Portuguese - Brazil', 'Romanian', 'Thai', 'Ukrainian', 'Vietnamese']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'Russian']
#
# j:  removed
# j:  removed
# j:  Russian
# ['Yes', 'No', 'Yes', 'No', 'No', 'No', 3, ['English', 'French', 'Russian']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain', 'Hungarian', 'Polish', 'Russian']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Hungarian
# j:  Polish
# j:  Russian
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'French', 'German', 'Italian', 'Spanish', 'Hungarian', 'Polish', 'Russian']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'Russian', 'French']
#
# j:  removed
# j:  Russian
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'No', 'No', 3, ['English', 'French', 'Russian']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'Russian', 'French']
#
# j:  removed
# j:  Russian
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'No', 'No', 3, ['English', 'French', 'Russian']]
#
#
#
# List:  ['English', 'French']
#
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'No', 'No', 2, ['English', 'French']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'German', 'French', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Russian']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 6, ['English', 'French', 'German', 'Italian', 'Spanish', 'Russian']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Spanish - Spain', 'Italian', 'Czech', 'Polish', 'Russian']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Czech
# j:  Polish
# j:  Russian
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'French', 'German', 'Italian', 'Spanish', 'Czech', 'Polish', 'Russian']]
#
#
#
# List:  ['English', 'French', 'German']
#
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'No', 'No', 3, ['English', 'French', 'German']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Czech', 'Polish', 'Russian']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Czech
# j:  Polish
# j:  Russian
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'French', 'German', 'Italian', 'Spanish', 'Czech', 'Polish', 'Russian']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Japanese', 'Korean', 'Portuguese', 'Russian', 'Traditional Chinese', 'Simplified Chinese', 'Spanish', 'Thai']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Portuguese
# j:  Russian
# j:  removed
# j:  removed
# j:  removed
# j:  Thai
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 11, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Japanese', 'Korean', 'Portuguese', 'Russian', 'Thai']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain', 'Russian']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 6, ['English', 'French', 'German', 'Italian', 'Spanish', 'Russian']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Polish', 'Russian', 'Japanese']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Polish
# j:  Russian
# j:  Japanese
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'French', 'German', 'Italian', 'Spanish', 'Polish', 'Russian', 'Japanese']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Polish', 'Russian', 'Japanese']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Polish
# j:  Russian
# j:  Japanese
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'French', 'German', 'Italian', 'Spanish', 'Polish', 'Russian', 'Japanese']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'Polish', 'Russian']
#
# j:  removed
# j:  Polish
# j:  Russian
# ['Yes', 'No', 'No', 'No', 'No', 'No', 3, ['English', 'Polish', 'Russian']]
#
#
#
# List:  ['English', 'Polish', 'Russian']
#
# j:  removed
# j:  Polish
# j:  Russian
# ['Yes', 'No', 'No', 'No', 'No', 'No', 3, ['English', 'Polish', 'Russian']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German']
#
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'No', 'No', 3, ['English', 'French', 'German']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'German']
#
# j:  removed
# j:  removed
# ['Yes', 'No', 'No', 'Yes', 'No', 'No', 2, ['English', 'German']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'Italian']
#
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 3, ['English', 'French', 'Italian']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain', 'Danish', 'Dutch', 'Finnish', 'Norwegian', 'Swedish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Danish
# j:  Dutch
# j:  Finnish
# j:  Norwegian
# j:  Swedish
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 10, ['English', 'French', 'German', 'Italian', 'Spanish', 'Danish', 'Dutch', 'Finnish', 'Norwegian', 'Swedish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Czech', 'Polish', 'Russian']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Czech
# j:  Polish
# j:  Russian
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'French', 'German', 'Italian', 'Spanish', 'Czech', 'Polish', 'Russian']]
#
#
#
# List:  ['English', 'French', 'German', 'Spanish - Spain', 'Italian', 'Russian', 'Simplified Chinese', 'Traditional Chinese', 'Czech', 'Polish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# j:  removed
# j:  removed
# j:  Czech
# j:  Polish
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 9, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Russian', 'Czech', 'Polish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Russian', 'Polish', 'Simplified Chinese', 'Traditional Chinese', 'Czech', 'Spanish - Spain', 'Japanese']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# j:  Polish
# j:  removed
# j:  removed
# j:  Czech
# j:  removed
# j:  Japanese
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 10, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Russian', 'Polish', 'Czech', 'Japanese']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'German']
#
# j:  removed
# j:  removed
# ['Yes', 'No', 'No', 'Yes', 'No', 'No', 2, ['English', 'German']]
#
#
#
# List:  ['English', 'German']
#
# j:  removed
# j:  removed
# ['Yes', 'No', 'No', 'Yes', 'No', 'No', 2, ['English', 'German']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'German', 'Italian', 'Russian', 'Simplified Chinese', 'Traditional Chinese', 'French', 'Korean']
#
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# j:  removed
# j:  removed
# j:  removed
# j:  Korean
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 7, ['English', 'Chinese', 'French', 'German', 'Italian', 'Russian', 'Korean']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Dutch']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Dutch
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 6, ['English', 'French', 'German', 'Italian', 'Spanish', 'Dutch']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Spanish - Spain', 'Russian']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# ['Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 5, ['English', 'French', 'German', 'Spanish', 'Russian']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'Russian', 'German', 'French']
#
# j:  removed
# j:  Russian
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'No', 'No', 4, ['English', 'French', 'German', 'Russian']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'Russian', 'French', 'German', 'Spanish - Spain', 'Italian', 'Japanese', 'Traditional Chinese']
#
# j:  removed
# j:  Russian
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese
# j:  removed
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 8, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Russian', 'Japanese']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Spanish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 4, ['English', 'French', 'German', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 4, ['English', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'German']
#
# j:  removed
# j:  removed
# ['Yes', 'No', 'No', 'Yes', 'No', 'No', 2, ['English', 'German']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# ...
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'German', 'French']
#
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'No', 'No', 3, ['English', 'French', 'German']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Polish', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Polish
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 6, ['English', 'French', 'German', 'Italian', 'Spanish', 'Polish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Japanese (all with full audio support)']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese (all with full audio support)
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 6, ['English', 'French', 'German', 'Italian', 'Spanish', 'Japanese (all with full audio support)']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish', 'Japanese (all with full audio support)']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese (all with full audio support)
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 6, ['English', 'French', 'German', 'Italian', 'Spanish', 'Japanese (all with full audio support)']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Spanish - Spain', 'Italian']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'Spanish - Spain', 'Italian', 'German']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French']
#
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'No', 'No', 2, ['English', 'French']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French']
#
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'No', 'No', 2, ['English', 'French']]
#
#
#
# List:  ['English', 'French']
#
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'No', 'No', 2, ['English', 'French']]
#
#
#
# List:  ['English', 'French', 'German', 'Spanish - Spain', 'Italian']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'Spanish - Spain', 'Italian', 'German']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'No', 'Yes', 3, ['English', 'French', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Japanese', 'Korean', 'Portuguese - Brazil', 'Russian', 'Simplified Chinese', 'Traditional Chinese']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese
# j:  Korean
# j:  Portuguese - Brazil
# j:  Russian
# j:  removed
# j:  removed
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 10, ['English', 'Chinese', 'French', 'German', 'Italian', 'Spanish', 'Japanese', 'Korean', 'Portuguese - Brazil', 'Russian']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish', 'Dutch', 'Danish', 'Norwegian', 'Swedish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Dutch
# j:  Danish
# j:  Norwegian
# j:  Swedish
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 9, ['English', 'French', 'German', 'Italian', 'Spanish', 'Dutch', 'Danish', 'Norwegian', 'Swedish']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish', 'Dutch', 'Danish', 'Norwegian', 'Swedish']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Dutch
# j:  Danish
# j:  Norwegian
# j:  Swedish
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 9, ['English', 'French', 'German', 'Italian', 'Spanish', 'Dutch', 'Danish', 'Norwegian', 'Swedish']]
#
#
#
# List:  ['English', 'French', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'No', 'Yes', 3, ['English', 'French', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'Italian', 'Dutch', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  Dutch
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 5, ['English', 'French', 'Italian', 'Spanish', 'Dutch']]
#
#
#
# List:  ['English', 'French', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'No', 'Yes', 3, ['English', 'French', 'Spanish']]
#
#
#
# List:  ['English', 'German']
#
# j:  removed
# j:  removed
# ['Yes', 'No', 'No', 'Yes', 'No', 'No', 2, ['English', 'German']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'Russian']
#
# j:  removed
# j:  Russian
# ['Yes', 'No', 'No', 'No', 'No', 'No', 2, ['English', 'Russian']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'Russian']
#
# j:  removed
# j:  Russian
# ['Yes', 'No', 'No', 'No', 'No', 'No', 2, ['English', 'Russian']]
#
#
#
# List:  ['English', 'French', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'No', 'Yes', 3, ['English', 'French', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English', 'French', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 4, ['English', 'French', 'Italian', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  []
#
# ['No', 'No', 'No', 'No', 'No', 'No', 0, []]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain', 'Russian', 'Czech', 'Polish', 'Hungarian']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Russian
# j:  Czech
# j:  Polish
# j:  Hungarian
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 9, ['English', 'French', 'German', 'Italian', 'Spanish', 'Russian', 'Czech', 'Polish', 'Hungarian']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Japanese', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  Japanese
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 6, ['English', 'French', 'German', 'Italian', 'Spanish', 'Japanese']]
#
#
#
# List:  ['English', 'French', 'German', 'Italian', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English']
#
# j:  removed
# ['Yes', 'No', 'No', 'No', 'No', 'No', 1, ['English']]
#
#
#
# List:  ['English', 'French', 'Italian', 'German', 'Spanish - Spain']
#
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# j:  removed
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 5, ['English', 'French', 'German', 'Italian', 'Spanish']]

# %%
newlang.to_csv('languages.csv', index=False)
